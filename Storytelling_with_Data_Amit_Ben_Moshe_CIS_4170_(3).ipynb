# %% [markdown]
# <a href="https://colab.research.google.com/github/amitbenmoshe/Storytelling-with-Data/blob/main/Storytelling_with_Data_Amit_Ben_Moshe_CIS_4170_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import altair as alt

# Load music data into a Pandas DataFrame
music_df = pd.read_csv("Music_Mental_Health.csv")
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
# Create an Altair selection
selection = alt.selection_multi(fields=['Fav genre'], bind='legend')

# Create an Altair chart with interactivity
chart = alt.Chart(music_df).mark_bar().encode(
    y=alt.Y('Fav genre:N', sort=alt.EncodingSortField('sum(Hours per day)', order='descending')),
    x='sum(Hours per day):Q',
    color=alt.condition(selection, 'Fav genre:N', alt.value('gray')),
    tooltip=['Fav genre:N', 'sum(Hours per day):Q']
).properties(
    width=600,
    height=400,
    title='Music Listening Habits'
).add_selection(selection)

chart
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd

# Load data
music_df = pd.read_csv('Music_Mental_Health.csv')

# Define selection
selection = alt.selection_multi(fields=['Music effects'], bind='legend')

# Define chart
chart = alt.Chart(music_df).mark_bar().encode(
    x='count()',
    y='Music effects',
    color=alt.condition(selection, 'Music effects', alt.value('gray')),
    tooltip=['Music effects', 'count()']
).properties(
    width=600,
    height=400,
    title='Effects of Music on Mental Health'
).add_selection(selection)

# Add interactivity
chart.interactive()
# Out:
# alt.Chart(...)
